# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Stock_Market\Data\Nifty50_Excel\Jan2024.csv', encoding= 'unicode_escape')

# %%
df.head()
# Out:
#        Symbol                     Security Name         Industry  Close Price  \
# 0         NaN                               NaN              NaN          NaN
# 1    ADANIENT            Adani Enterprises Ltd.  Metals & Mining      3142.00
# 2  ADANIPORTS  Adani Ports and Special Economic         Services      1207.65
# 3         NaN                         Zone Ltd.              NaN          NaN
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.       Healthcare      6352.95
#
#      Index Mcap Weightage
# 0  (Rs. Crores)       (%)
# 1         82383      0.87
# 2         88696      0.93
# 3           NaN       NaN
# 4         63942      0.67

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  51 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     51 non-null     object
#  5   Weightage      51 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.6+ KB

# %%
df.shape
# Out:
# (52, 6)

# %%
print(df)
# Out:
#         Symbol                         Security Name  \
# 0          NaN                                   NaN
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 3          NaN                             Zone Ltd.
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# 16     DRREDDY         Dr. Reddy's Laboratories Ltd.
# ...

# %%
df.head()
# Out:
#        Symbol                     Security Name         Industry  Close Price  \
# 0         NaN                               NaN              NaN          NaN
# 1    ADANIENT            Adani Enterprises Ltd.  Metals & Mining      3142.00
# 2  ADANIPORTS  Adani Ports and Special Economic         Services      1207.65
# 3         NaN                         Zone Ltd.              NaN          NaN
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.       Healthcare      6352.95
#
#      Index Mcap Weightage
# 0  (Rs. Crores)       (%)
# 1         82383      0.87
# 2         88696      0.93
# 3           NaN       NaN
# 4         63942      0.67

# %%
pd.isnull(df)
# Out:
#     Symbol  Security Name  Industry  Close Price  Index Mcap  Weightage
# 0     True           True      True         True       False      False
# 1    False          False     False        False       False      False
# 2    False          False     False        False       False      False
# 3     True          False      True         True        True       True
# 4    False          False     False        False       False      False
# 5    False          False     False        False       False      False
# 6    False          False     False        False       False      False
# 7    False          False     False        False       False      False
# 8    False          False     False        False       False      False
# 9    False          False     False        False       False      False
# 10   False          False     False        False       False      False
# 11   False          False     False        False       False      False
# ...

# %%
pd.isnull(df).sum()
# Out:
# Symbol           2
# Security Name    1
# Industry         2
# Close Price      2
# Index Mcap       1
# Weightage        1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1      3142.00      82383      0.87
# 2      1207.65      88696      0.93
# 4      6352.95      63942      0.67
# 5      2957.85     133347      1.40
# 6      1067.75     296335      3.12

# %%
pd.isnull(df)
# Out:
#     Symbol  Security Name  Industry  Close Price  Index Mcap  Weightage
# 1    False          False     False        False       False      False
# 2    False          False     False        False       False      False
# 4    False          False     False        False       False      False
# 5    False          False     False        False       False      False
# 6    False          False     False        False       False      False
# 7    False          False     False        False       False      False
# 8    False          False     False        False       False      False
# 9    False          False     False        False       False      False
# 10   False          False     False        False       False      False
# 11   False          False     False        False       False      False
# 12   False          False     False        False       False      False
# 13   False          False     False        False       False      False
# ...

# %%
pd.isnull(df).sum()
# Out:
# Symbol           0
# Security Name    0
# Industry         0
# Close Price      0
# Index Mcap       0
# Weightage        0
# dtype: int64

# %%
df.shape
# Out:
# (50, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     object
#  5   Weightage      50 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.7+ KB

# %%
df['Index Mcap'] = df['Index Mcap'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     int32
#  5   Weightage      50 non-null     object
# dtypes: float64(1), int32(1), object(4)
# memory usage: 2.5+ KB

# %%
df['Weightage'] = df['Weightage'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     int32
#  5   Weightage      50 non-null     float64
# dtypes: float64(2), int32(1), object(3)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (50, 6)

# %%
dup = df.drop_duplicates()

# %%
print(dup)
# Out:
#         Symbol                         Security Name  \
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# 16     DRREDDY         Dr. Reddy's Laboratories Ltd.
# 17   EICHERMOT                    Eicher Motors Ltd.
# 18      GRASIM                Grasim Industries Ltd.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     int32
#  5   Weightage      50 non-null     float64
# dtypes: float64(2), int32(1), object(3)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (50, 6)

# %%
drop = df.dropna()
print(drop)
# Out:
#         Symbol                         Security Name  \
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# 16     DRREDDY         Dr. Reddy's Laboratories Ltd.
# 17   EICHERMOT                    Eicher Motors Ltd.
# 18      GRASIM                Grasim Industries Ltd.
# ...

# %%
dup = drop.drop_duplicates()

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price  Index Mcap  Weightage
# 1      3142.00       82383       0.87
# 2      1207.65       88696       0.93
# 4      6352.95       63942       0.67
# 5      2957.85      133347       1.40
# 6      1067.75      296335       3.12

# %%
df.shape
# Out:
# (50, 6)

# %%
df.to_csv(r'C:\Stock_Market\Data\Nifty50_Excel - Clean\clean1_Jan2024.csv', index = False)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 da = pd.read_csv(r'C:\Stock_Market\Data\Nifty50_Excel\Feb2024', encoding = 'unicode_escape')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv(r'C:\Stock_Market\Data\Nifty50_Excel\Feb2024.csv', encoding= 'unicode_escape')

# %%
df.head()
# Out:
#        Symbol                     Security Name         Industry  Close Price  \
# 0         NaN                               NaN              NaN          NaN
# 1    ADANIENT            Adani Enterprises Ltd.  Metals & Mining       3285.4
# 2  ADANIPORTS  Adani Ports and Special Economic         Services       1320.5
# 3         NaN                         Zone Ltd.              NaN          NaN
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.       Healthcare       6101.6
#
#      Index Mcap Weightage
# 0  (Rs. Crores)       (%)
# 1         86143      0.90
# 2         96984      1.01
# 3           NaN       NaN
# 4         61412      0.64

# %%
df.shape
# Out:
# (52, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Symbol                         Security Name  \
# 0          NaN                                   NaN
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 3          NaN                             Zone Ltd.
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         Symbol                         Security Name  \
# 0          NaN                                   NaN
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 3          NaN                             Zone Ltd.
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# ...

# %%
df.shape
# Out:
# (52, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of         Symbol                         Security Name  \
# 0          NaN                                   NaN
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 3          NaN                             Zone Ltd.
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  51 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     51 non-null     object
#  5   Weightage      51 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.6+ KB

# %%
df.head()
# Out:
#        Symbol                     Security Name         Industry  Close Price  \
# 0         NaN                               NaN              NaN          NaN
# 1    ADANIENT            Adani Enterprises Ltd.  Metals & Mining       3285.4
# 2  ADANIPORTS  Adani Ports and Special Economic         Services       1320.5
# 3         NaN                         Zone Ltd.              NaN          NaN
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.       Healthcare       6101.6
#
#      Index Mcap Weightage
# 0  (Rs. Crores)       (%)
# 1         86143      0.90
# 2         96984      1.01
# 3           NaN       NaN
# 4         61412      0.64

# %%
pd.isnull(df).sum()
# Out:
# Symbol           2
# Security Name    1
# Industry         2
# Close Price      2
# Index Mcap       1
# Weightage        1
# dtype: int64

# %%
drop = df.dropna()

# %%
pd.isnull(df)
# Out:
#     Symbol  Security Name  Industry  Close Price  Index Mcap  Weightage
# 1    False          False     False        False       False      False
# 2    False          False     False        False       False      False
# 4    False          False     False        False       False      False
# 5    False          False     False        False       False      False
# 6    False          False     False        False       False      False
# 7    False          False     False        False       False      False
# 8    False          False     False        False       False      False
# 9    False          False     False        False       False      False
# 10   False          False     False        False       False      False
# 11   False          False     False        False       False      False
# 12   False          False     False        False       False      False
# 13   False          False     False        False       False      False
# ...

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1       3285.4      86143      0.90
# 2       1320.5      96984      1.01
# 4       6101.6      61412      0.64
# 5       2821.9     127218      1.32
# 6       1075.1     298375      3.10

# %%
pd.isnull(df).sum()
# Out:
# Symbol           0
# Security Name    0
# Industry         0
# Close Price      0
# Index Mcap       0
# Weightage        0
# dtype: int64

# %%
dup = df.drop_duplicates()

# %%
df.shape
# Out:
# (50, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     object
#  5   Weightage      50 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.7+ KB

# %%
df['Index Mcap'] = df['Index Mcap'].astype('int')

# %%
df['Weightage'] = df['Weightage'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     int32
#  5   Weightage      50 non-null     float64
# dtypes: float64(2), int32(1), object(3)
# memory usage: 2.5+ KB

# %%
df.to_csv(r'C:\Stock_Market\Data\Nifty50_Excel - Clean\clean1_Feb2024.csv', index =False)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df =pd.read_csv(r'C:\Stock_Market\Data\Nifty50_Excel\March2024.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#     ï»¿Symbol                     Security Name         Industry  Close Price  \
# 0         NaN                               NaN              NaN          NaN
# 1    ADANIENT            Adani Enterprises Ltd.  Metals & Mining      3197.10
# 2  ADANIPORTS  Adani Ports and Special Economic         Services      1341.85
# 3         NaN                         Zone Ltd.              NaN          NaN
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.       Healthcare      6356.80
#
#      Index Mcap Weightage
# 0  (Rs. Crores)       (%)
# 1         83828      0.85
# 2         98552      1.00
# 3           NaN       NaN
# 4         63981      0.65

# %%
df.shape
# Out:
# (52, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of      ï»¿Symbol                         Security Name  \
# 0          NaN                                   NaN
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 3          NaN                             Zone Ltd.
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ï»¿Symbol      50 non-null     object
#  1   Security Name  51 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     51 non-null     object
#  5   Weightage      51 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.6+ KB

# %%
df.dropna()
# Out:
#      ï»¿Symbol                         Security Name  \
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# 16     DRREDDY         Dr. Reddy's Laboratories Ltd.
# 17   EICHERMOT                    Eicher Motors Ltd.
# 18      GRASIM                Grasim Industries Ltd.
# ...

# %%
pd.isnull(df)
# Out:
#     ï»¿Symbol  Security Name  Industry  Close Price  Index Mcap  Weightage
# 0        True           True      True         True       False      False
# 1       False          False     False        False       False      False
# 2       False          False     False        False       False      False
# 3        True          False      True         True        True       True
# 4       False          False     False        False       False      False
# 5       False          False     False        False       False      False
# 6       False          False     False        False       False      False
# 7       False          False     False        False       False      False
# 8       False          False     False        False       False      False
# 9       False          False     False        False       False      False
# 10      False          False     False        False       False      False
# ...

# %%
pd.isnull(df).sum()
# Out:
# ï»¿Symbol        2
# Security Name    1
# Industry         2
# Close Price      2
# Index Mcap       1
# Weightage        1
# dtype: int64

# %%
df.dropna(inplace =True)

# %%
pd.isnull(df).sum()
# Out:
# ï»¿Symbol        0
# Security Name    0
# Industry         0
# Close Price      0
# Index Mcap       0
# Weightage        0
# dtype: int64

# %%
df.rename(columns= {'ï»¿Symbol':'Name'}, inplace = True)
# Out:
#           Name                         Security Name  \
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# 16     DRREDDY         Dr. Reddy's Laboratories Ltd.
# 17   EICHERMOT                    Eicher Motors Ltd.
# 18      GRASIM                Grasim Industries Ltd.
# ...

# %%
df.head()
# Out:
#     ï»¿Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1      3197.10      83828      0.85
# 2      1341.85      98552      1.00
# 4      6356.80      63981      0.65
# 5      2846.75     128338      1.30
# 6      1047.20     297312      3.02

# %%
df.rename(columns= {'ï»¿Symbol':'Name'}, inplace = True)

# %%
df.head()
# Out:
#          Name                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1      3197.10      83828      0.85
# 2      1341.85      98552      1.00
# 4      6356.80      63981      0.65
# 5      2846.75     128338      1.30
# 6      1047.20     297312      3.02

# %%
df.rename(columns= {'Name':'Sym'}, inplace = True)

# %%
df.head()
# Out:
#           Sym                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1      3197.10      83828      0.85
# 2      1341.85      98552      1.00
# 4      6356.80      63981      0.65
# 5      2846.75     128338      1.30
# 6      1047.20     297312      3.02

# %%
df.rename(columns= {'Sym':'Symbol'}, inplace = True)

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1      3197.10      83828      0.85
# 2      1341.85      98552      1.00
# 4      6356.80      63981      0.65
# 5      2846.75     128338      1.30
# 6      1047.20     297312      3.02

# %%
df.drop_duplicates()
# Out:
#         Symbol                         Security Name  \
# 1     ADANIENT                Adani Enterprises Ltd.
# 2   ADANIPORTS      Adani Ports and Special Economic
# 4   APOLLOHOSP      Apollo Hospitals Enterprise Ltd.
# 5   ASIANPAINT                     Asian Paints Ltd.
# 6     AXISBANK                        Axis Bank Ltd.
# 7   BAJAJ-AUTO                       Bajaj Auto Ltd.
# 8   BAJFINANCE                    Bajaj Finance Ltd.
# 9   BAJAJFINSV                    Bajaj Finserv Ltd.
# 10        BPCL     Bharat Petroleum Corporation Ltd.
# 11  BHARTIARTL                    Bharti Airtel Ltd.
# 12   BRITANNIA             Britannia Industries Ltd.
# 13       CIPLA                            Cipla Ltd.
# 14   COALINDIA                       Coal India Ltd.
# 15    DIVISLAB              Divi's Laboratories Ltd.
# 16     DRREDDY         Dr. Reddy's Laboratories Ltd.
# 17   EICHERMOT                    Eicher Motors Ltd.
# 18      GRASIM                Grasim Industries Ltd.
# ...

# %%
df.shape
# Out:
# (50, 6)

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price Index Mcap Weightage
# 1      3197.10      83828      0.85
# 2      1341.85      98552      1.00
# 4      6356.80      63981      0.65
# 5      2846.75     128338      1.30
# 6      1047.20     297312      3.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     object
#  5   Weightage      50 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 2.7+ KB

# %%
df['Weightage'] = df['Weightage'].astype('float')

# %%
df['Index Mcap'] = df['Index Mcap'].astype('float')

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price  Index Mcap  Weightage
# 1      3197.10     83828.0       0.85
# 2      1341.85     98552.0       1.00
# 4      6356.80     63981.0       0.65
# 5      2846.75    128338.0       1.30
# 6      1047.20    297312.0       3.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     float64
#  5   Weightage      50 non-null     float64
# dtypes: float64(3), object(3)
# memory usage: 2.7+ KB

# %%
df['Index Mcap'] = df['Index Mcap'].astype('int')

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price  Index Mcap  Weightage
# 1      3197.10       83828       0.85
# 2      1341.85       98552       1.00
# 4      6356.80       63981       0.65
# 5      2846.75      128338       1.30
# 6      1047.20      297312       3.02

# %%
df.shape
# Out:
# (50, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 1 to 51
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Symbol         50 non-null     object
#  1   Security Name  50 non-null     object
#  2   Industry       50 non-null     object
#  3   Close Price    50 non-null     float64
#  4   Index Mcap     50 non-null     int32
#  5   Weightage      50 non-null     float64
# dtypes: float64(2), int32(1), object(3)
# memory usage: 2.5+ KB

# %%
df.to_csv(r'C:\Stock_Market\Data\Nifty50_Excel - Clean\clean1_March2024.csv', index =False)

# %%
df.head()
# Out:
#        Symbol                     Security Name            Industry  \
# 1    ADANIENT            Adani Enterprises Ltd.     Metals & Mining
# 2  ADANIPORTS  Adani Ports and Special Economic            Services
# 4  APOLLOHOSP  Apollo Hospitals Enterprise Ltd.          Healthcare
# 5  ASIANPAINT                 Asian Paints Ltd.   Consumer Durables
# 6    AXISBANK                    Axis Bank Ltd.  Financial Services
#
#    Close Price  Index Mcap  Weightage
# 1      3197.10       83828       0.85
# 2      1341.85       98552       1.00
# 4      6356.80       63981       0.65
# 5      2846.75      128338       1.30
# 6      1047.20      297312       3.02
